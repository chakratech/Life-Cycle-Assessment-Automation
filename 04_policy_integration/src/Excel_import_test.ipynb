# %%
import bw2data as bd
import bw2io as bi
import bw2calc as bc

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
print("bw2data version", bd.__version__)
print("bw2io version", bi.__version__)
print("bw2calc version", bi.__version__)
# Out:
# bw2data version (4, 5, 1)
# bw2io version 0.9.14
# bw2calc version 0.9.14

# %%
bd.projects
# Out:
# Brightway2 projects manager with 3 objects:
# 	bw25-tuto
# 	bw25-tutorial
# 	default
# Use `projects.report()` to get a report on all projects.

# %%
bd.projects.set_current("import_excel")
# Out:
# 12:36:20-0800 [info     ] Applying automatic update: 4.0 database search directories FTS5
# 12:36:20-0800 [info     ] Reindexing database biosphere3

# %%
bd.projects
# Out:
# Brightway2 projects manager with 3 objects:
# 	bw25-tuto
# 	bw25-tutorial
# 	default
# Use `projects.report()` to get a report on all projects.

# %%
bd.databases
# Out:
# Databases dictionary with 0 objects

# %%
bi.remote.install_project('ecoinvent-3.9.1-biosphere', 'import_excel')
# Out:
# Restoring project backup archive - this could take a few minutes...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 bi.remote.install_project('ecoinvent-3.9.1-biosphere', 'import_excel')
#
# File ~/miniconda3/envs/env_bw25/lib/python3.11/site-packages/bw2io/remote.py:112, in install_project(project_key, project_name, projects_config, url, overwrite_existing, __recursive)
#     107     download_with_progressbar(
#     108         url=urljoin(url, filename), filename=filename, dirpath=cache_dir
#     109     )
#     111 try:
# --> 112     return restore_project_directory(
#     113         fp=fp, project_name=project_name, overwrite_existing=overwrite_existing
#     114     )
#     115 except EOFError:
#     116     # Corrupt or incomplete zip archive
#     117     fp.unlink()
#
# ...

# %%
bd.databases
# Out:
# Databases dictionary with 1 object(s):
# 	biosphere3

# %%
bd.projects.delete_project(name='import_excel', delete_dir=True)
# Out:
# 'default'
